# %% [markdown]
# # Get Dataset

# %%
# !pip install roboflow
# !pip install ultralytics

from roboflow import Roboflow
rf = Roboflow(api_key="8x60Dt5D8BG6aLBvHXyJ")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
#   Using cached roboflow-1.1.28-py3-none-any.whl.metadata (9.3 kB)
# ...
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl.metadata (722 bytes)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# ...
#   Using cached opencv_python_headless-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached roboflow-1.1.28-py3-none-any.whl (74 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Using cached opencv_python_headless-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# ...

# %%
import torch.backends
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device = torch.device("cuda" if torch.cuda.is_available() else device)
device
# Out:
# device(type='mps')

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 device='cpu'
# results = model(source="yolov5l6u.pt", show=True, conf=0.05, save=True, device='mps', data={dataset.location}/data.yaml, epochs=100, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.8 🚀 Python-3.12.2 torch-2.3.0 CPU (Apple M1)
# ...
